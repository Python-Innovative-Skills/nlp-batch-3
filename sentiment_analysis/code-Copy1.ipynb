# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
chunk_list = []
#num_rows #skip_rows
def load_data(file_path,size):
    for chunk in pd.read_csv(file_path, header=None, encoding='latin-1', 
                             names=['target','id','date','meta','user','text'],chunksize=size):
        print(chunk)
        chunk_list.append(chunk)
#     df = pd.read_csv(file_path, header=None, encoding='latin-1', names=['target','id','date','meta','user','text'])
#     df['sentiment'] = df['target'].apply(lambda x: 'positive' if x==4 else 'negative')
#     df.drop(columns=['id','date','meta','user'], inplace=True)
#     print(df.head())
    return chunk_list

# %%
file_path ='sentiment140.csv'
size = 1000

df = load_data(file_path,size)
df_concat =  pd.concat(df, ignore_index=True)
# Select the first 10 rows
# df_subset = df.head(10)
# Out:
#      target          id                          date      meta  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3         0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4         0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ..      ...         ...                           ...       ...
# 995       0  1468055262  Mon Apr 06 23:28:39 PDT 2009  NO_QUERY
# 996       0  1468055266  Mon Apr 06 23:28:41 PDT 2009  NO_QUERY
# 997       0  1468055472  Mon Apr 06 23:28:43 PDT 2009  NO_QUERY
# 998       0  1468055604  Mon Apr 06 23:28:45 PDT 2009  NO_QUERY
# 999       0  1468055791  Mon Apr 06 23:28:49 PDT 2009  NO_QUERY
#
#                 user                                               text
# 0    _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1      scotthamilton  is upset that he can't update his Facebook by ...
# 2           mattycus  @Kenichan I dived many times for the ball. Man...
# 3            ElleCTF    my whole body feels itchy and like its on fire
# 4             Karoli  @nationwideclass no, it's not behaving at all....
# ..               ...                                                ...
# 995      LarryEisner  @dkoenigs thanks man.  I'm so very grateful.  ...
# 996   ohmigosh_dusti  @t_wolfe  i miss u too. i'm totally comin back...
# 997   tiphaniebrooke  @sniffinglue ohhh. I love it. ps I'm sad we di...
# 998       rinahannah          And somehow I still end up in this place
# 999             ecjc         @kisluvkis oh that is very sad, poor boy.
#
# [1000 rows x 6 columns]
#       target          id                          date      meta  \
# 1000       0  1468055852  Mon Apr 06 23:28:50 PDT 2009  NO_QUERY
# 1001       0  1468056316  Mon Apr 06 23:28:58 PDT 2009  NO_QUERY
# 1002       0  1468056420  Mon Apr 06 23:29:00 PDT 2009  NO_QUERY
# 1003       0  1468060375  Mon Apr 06 23:30:10 PDT 2009  NO_QUERY
# 1004       0  1468060378  Mon Apr 06 23:30:10 PDT 2009  NO_QUERY
# ...      ...         ...                           ...       ...
# 1995       0  1468280681  Tue Apr 07 00:43:16 PDT 2009  NO_QUERY
# 1996       0  1468280970  Tue Apr 07 00:43:22 PDT 2009  NO_QUERY
# 1997       0  1468281170  Tue Apr 07 00:43:26 PDT 2009  NO_QUERY
# 1998       0  1468281205  Tue Apr 07 00:43:29 PDT 2009  NO_QUERY
# 1999       0  1468281484  Tue Apr 07 00:43:33 PDT 2009  NO_QUERY
#
#                user                                               text
# 1000    Saphyre1969  @JonathanRKnight @silver_tulip27 Um, that woul...
# 1001    nurainiffah      I'm doing my homework. It's gosh darn hard!!
# 1002      francheza  definitely no vacation for me...   http://plur...
# 1003     BrandesAsh  'study group extraordinare' about to leave cam...
# 1004  Buffaliscious  Why can't airfare go down? Or, why do I have t...
# ...             ...                                                ...
# 1995         chomma                          @roxy_yeah yep a loser.
# 1996        EvilSue  and finito! All bathroom contractors been thru...
# 1997      lexikitty  @caitlinaudrey awww!  that sucks! are you goin...
# 1998       terrajen  Sorry, SF. Rescheduling my SF trip for this co...
# 1999        MonBon_  2morw  I get my blasted wisdom teeth pulled! N...
#
# [1000 rows x 6 columns]
#       target          id                          date      meta  \
# 2000       0  1468281702  Tue Apr 07 00:43:38 PDT 2009  NO_QUERY
# 2001       0  1468281949  Tue Apr 07 00:43:43 PDT 2009  NO_QUERY
# 2002       0  1468281976  Tue Apr 07 00:43:44 PDT 2009  NO_QUERY
# 2003       0  1468281977  Tue Apr 07 00:43:44 PDT 2009  NO_QUERY
# 2004       0  1468282327  Tue Apr 07 00:43:55 PDT 2009  NO_QUERY
# ...      ...         ...                           ...       ...
# 2995       0  1468493731  Tue Apr 07 02:00:46 PDT 2009  NO_QUERY
# 2996       0  1468494392  Tue Apr 07 02:00:58 PDT 2009  NO_QUERY
# 2997       0  1468494732  Tue Apr 07 02:01:04 PDT 2009  NO_QUERY
# 2998       0  1468494789  Tue Apr 07 02:01:09 PDT 2009  NO_QUERY
# 2999       0  1468494849  Tue Apr 07 02:01:10 PDT 2009  NO_QUERY
#
#                 user                                               text
# 2000  RichardFWatson  Morning twitterati...... Large coffee and a ba...
# 2001     lucienfoort  hitting the gym! afterwards looking forward to...
# 2002  fionalvsdarren                    doesnt  want to go to work lol
# 2003        coachamy  @SherriGarrity Sorry I missed responding yeste...
# 2004    psychosnoopy               i wanna come with them to bohol!!!!
# ...              ...                                                ...
# 2995       shortyyyy  @ZoeAimee I'm trying to research some dude for...
# 2996   xhardtoforget  just got up, pshhh going on the trampoline, ev...
# 2997    amielia_1991                                          Homework
# 2998          dessey  @pmarnandus re: daily gossip.. well the twitte...
# 2999          downsy  http://twitpic.com/2y7bg - This is Ashley from...
#
# [1000 rows x 6 columns]
#       target          id                          date      meta  \
# 3000       0  1468495130  Tue Apr 07 02:01:15 PDT 2009  NO_QUERY
# 3001       0  1468495292  Tue Apr 07 02:01:18 PDT 2009  NO_QUERY
# 3002       0  1468495833  Tue Apr 07 02:01:29 PDT 2009  NO_QUERY
# 3003       0  1468495877  Tue Apr 07 02:01:30 PDT 2009  NO_QUERY
# 3004       0  1468496029  Tue Apr 07 02:01:34 PDT 2009  NO_QUERY
# ...      ...         ...                           ...       ...
# 3995       0  1468720238  Tue Apr 07 03:21:36 PDT 2009  NO_QUERY
# 3996       0  1468720738  Tue Apr 07 03:21:47 PDT 2009  NO_QUERY
# 3997       0  1468720797  Tue Apr 07 03:21:48 PDT 2009  NO_QUERY
# 3998       0  1468720998  Tue Apr 07 03:21:52 PDT 2009  NO_QUERY
# 3999       0  1468721004  Tue Apr 07 03:21:52 PDT 2009  NO_QUERY
#
#                 user                                               text
# 3000        carakole  @islandiva147 I sent u a tweet yesterday but I...
# 3001  lordofthedarts                            English revision class
# 3002        Dibbs_ZA  Laptop died on me yesterday    Have to reinsta...
# 7001  paisleymelody                         @kayaaa i miss you too bb
# 7002        theaofa              @Fasshonaburu Oh no! That's not good
# 7003     krisweetea                              Last day in Chicago.
# 7004       glophead  RIP 94.7 The Globe. You will be missed.  Now I...
# ...             ...                                                ...
# 7995        Bagrant  @bradshawme the snow hit me in the eye and lit...
# 7996  _BooBooKitty_  My phone is off.   but I do have a new number ...
# 7997     laurenfoot  Arrrggghhhhhhhhh i cant put my picture up...it...
# 7998      Lindsey_D            @hypno_sadism   I am without words. Oy.
# 7999     Nessyjayne           there woz summin rng with tht cream egg
#
# [1000 rows x 6 columns]
#       target          id                          date      meta  \
# 8000       0  1470036251  Tue Apr 07 08:09:22 PDT 2009  NO_QUERY
# 8001       0  1470036602  Tue Apr 07 08:09:26 PDT 2009  NO_QUERY
# 8002       0  1470036673  Tue Apr 07 08:09:26 PDT 2009  NO_QUERY
# 8003       0  1470036712  Tue Apr 07 08:09:27 PDT 2009  NO_QUERY
# 8004       0  1470036738  Tue Apr 07 08:09:27 PDT 2009  NO_QUERY
# ...      ...         ...                           ...       ...
# 8995       0  1548558266  Fri Apr 17 21:17:26 PDT 2009  NO_QUERY
# 8996       0  1548558433  Fri Apr 17 21:17:28 PDT 2009  NO_QUERY
# 8997       0  1548558558  Fri Apr 17 21:17:30 PDT 2009  NO_QUERY
# 8998       0  1548558575  Fri Apr 17 21:17:30 PDT 2009  NO_QUERY
# 8999       0  1548558909  Fri Apr 17 21:17:33 PDT 2009  NO_QUERY
#
#                  user                                               text
# 8000        lindsaycb  @enoch111 Whoops. I got a little too happy. Do...
# 8001      InyanWicasa  @KatyLinda Wow! Kudos 2 U.  4yrs &amp; 3 mos.?...
# 8002         madrogue  There is a higher cop-to-donut ratio today, so...
# 8003      stevenray88  Missing his babe! I just want him to come back...
# 8004          CSiwiec  I'm getting really lazy with my Twitter updating
# ...               ...                                                ...
# 8995        Marcus105  @chenez awwww. and i didn't get to be the hero...
# 8996  NegativeCreep22  @TessAaaaah Ahh, this is how you reply!! I had...
# 8997     LEHUASUMMER_  @Nessiebear i really wanna see it! but no one ...
# 8998           JefTek  ouch following the #ASOT400 in TweetDeck excee...
# 8999         Mandie95                         Just landed. My ears hurt
#
# [1000 rows x 6 columns]
#       target          id                          date      meta  \
# 9000       0  1548559007  Fri Apr 17 21:17:34 PDT 2009  NO_QUERY
# 9001       0  1548559160  Fri Apr 17 21:17:36 PDT 2009  NO_QUERY
# 9002       0  1548573701  Fri Apr 17 21:20:11 PDT 2009  NO_QUERY
# 9003       0  1548573990  Fri Apr 17 21:20:14 PDT 2009  NO_QUERY
# 9004       0  1548574052  Fri Apr 17 21:20:14 PDT 2009  NO_QUERY
# ...      ...         ...                           ...       ...
# 9995       0  1550729779  Sat Apr 18 07:05:12 PDT 2009  NO_QUERY
# 9996       0  1550730633  Sat Apr 18 07:05:23 PDT 2009  NO_QUERY
# 9997       0  1550731192  Sat Apr 18 07:05:29 PDT 2009  NO_QUERY
# 9998       0  1550731281  Sat Apr 18 07:05:30 PDT 2009  NO_QUERY
# 1593997     katbirrell  Super excited about MSU Football  Got season t...
# 1593998        codedly  @firedustching ! hurhur. idk ... not sunday ):...
# 1593999      surferpam           @ivaaishah Ivaaaaa! me too!!  how r you?
#
# [1000 rows x 6 columns]
#          target          id                          date      meta  \
# 1594000       4  2192060688  Tue Jun 16 06:26:33 PDT 2009  NO_QUERY
# 1594001       4  2192060793  Tue Jun 16 06:26:34 PDT 2009  NO_QUERY
# 1594002       4  2192060863  Tue Jun 16 06:26:34 PDT 2009  NO_QUERY
# 1594003       4  2192060899  Tue Jun 16 06:26:34 PDT 2009  NO_QUERY
# 1594004       4  2192060952  Tue Jun 16 06:26:35 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1594995       4  2192271342  Tue Jun 16 06:46:53 PDT 2009  NO_QUERY
# 1594996       4  2192271480  Tue Jun 16 06:46:54 PDT 2009  NO_QUERY
# 1594997       4  2192271482  Tue Jun 16 06:46:54 PDT 2009  NO_QUERY
# 1594998       4  2192271552  Tue Jun 16 06:46:55 PDT 2009  NO_QUERY
# 1594999       4  2192271664  Tue Jun 16 06:46:55 PDT 2009  NO_QUERY
#
#                     user                                               text
# 1594000  realestatechick  @rmedina Morning Ray! Hope you have a fantasti...
# 1594001          Maridel  @ExcellentPres yese i ve already wrapped my pr...
# 1594002      skipper0112  Gooood morning!!! At work til 2. Then I have t...
# 1594003      misschatter  @HHReynolds Oops just missed the post  http://...
# 1594004          Weaserr  @HighPeaksResort it wouldn't be LP for us if i...
# ...                  ...                                                ...
# 1594995     nikkimarie83    anxious to serve dinner with everyone tonight!
# 1594996        _jeanjean                      @AC_1 Happy Birthday Andrew!
# 1594997  Shadowphoenix83  The return of my favorite webshow    fiveandah...
# 1594998       zigzagem92     @give_me_RAWRRR  what lesson do you have next?
# 1594999         Teradawn  @Carly_FTS Does that mean it's ready and I can...
#
# [1000 rows x 6 columns]
#          target          id                          date      meta  \
# 1595000       4  2192271714  Tue Jun 16 06:46:56 PDT 2009  NO_QUERY
# 1595001       4  2192271738  Tue Jun 16 06:46:56 PDT 2009  NO_QUERY
# 1595002       4  2192271752  Tue Jun 16 06:46:56 PDT 2009  NO_QUERY
# 1595003       4  2192271959  Tue Jun 16 06:46:57 PDT 2009  NO_QUERY
# 1595004       4  2192272140  Tue Jun 16 06:46:58 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1595995       4  2192559423  Tue Jun 16 07:12:58 PDT 2009  NO_QUERY
# 1595996       4  2192559523  Tue Jun 16 07:12:59 PDT 2009  NO_QUERY
# 1595997       4  2192559544  Tue Jun 16 07:12:59 PDT 2009  NO_QUERY
# 1595998       4  2192559566  Tue Jun 16 07:12:59 PDT 2009  NO_QUERY
# 1595999       4  2192559575  Tue Jun 16 07:12:59 PDT 2009  NO_QUERY
#
#                    user                                               text
# 1595000        horrgakx  Off to Whinlatter tonight, up through the fore...
# 1595001   talkTweetMeme  @Usha well keep in touch as we'll be pushing o...
# 1595002     meltingmama  @mzpuppie Bariatric Fusion is at the top of th...
# 1595003        faeshale                               Thank you @Raevyns.
# 1595004         missmei  @neopeo how do I do that from a bb. Tell me ho...
# ...                 ...                                                ...
# 1595995       bmarie427  @Jonasbrothers i love your new cd! i preordere...
TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 3199995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 3199996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 3199997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 3199998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 3199999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [3200000 rows x 6 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download necessary NLTK data files
nltk.download('punkt')
nltk.download('stopwords')

standard_stopwords = set(stopwords.words('english'))

# Print the standard stopwords
print("Standard Stopwords:")
print(sorted(standard_stopwords))  # Sorted for better readability
# Out:
# Standard Stopwords:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'itself', 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she's", 'should', "should've", 'shouldn', "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Dataset Preparation and Cleaning

# %%
def clean_prep_text(text):
    # Convert to lowercase
    text = text.lower()
    print("lowercase: ",text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    print("Remove Puncuation: ",text)
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    print("Remove stopwords: ",text)
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# %%
df_subset['cleaned_text'] = df_subset['text'].apply(clean_prep_text)

print("cleaned_text",df_subset['cleaned_text'])
# Out:
# lowercase:  @switchfoot http://twitpic.com/2y1zl - awww, that's a bummer.  you shoulda got david carr of third day to do it. ;d
# Remove Puncuation:  switchfoot httptwitpiccom2y1zl  awww thats a bummer  you shoulda got david carr of third day to do it d
# Remove stopwords:  switchfoot httptwitpiccom2y1zl  awww thats a bummer  you shoulda got david carr of third day to do it d
# lowercase:  is upset that he can't update his facebook by texting it... and might cry as a result  school today also. blah!
# Remove Puncuation:  is upset that he cant update his facebook by texting it and might cry as a result  school today also blah
# Remove stopwords:  is upset that he cant update his facebook by texting it and might cry as a result  school today also blah
# lowercase:  @kenichan i dived many times for the ball. managed to save 50%  the rest go out of bounds
# Remove Puncuation:  kenichan i dived many times for the ball managed to save 50  the rest go out of bounds
# Remove stopwords:  kenichan i dived many times for the ball managed to save 50  the rest go out of bounds
# lowercase:  my whole body feels itchy and like its on fire
# Remove Puncuation:  my whole body feels itchy and like its on fire
# Remove stopwords:  my whole body feels itchy and like its on fire
# lowercase:  @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because i can't see you all over there.
# Remove Puncuation:  nationwideclass no its not behaving at all im mad why am i here because i cant see you all over there
# Remove stopwords:  nationwideclass no its not behaving at all im mad why am i here because i cant see you all over there
# lowercase:  @kwesidei not the whole crew
# Remove Puncuation:  kwesidei not the whole crew
# Remove stopwords:  kwesidei not the whole crew
# lowercase:  need a hug
# Remove Puncuation:  need a hug
# Remove stopwords:  need a hug
# lowercase:  @loltrish hey  long time no see! yes.. rains a bit ,only a bit  lol , i'm fine thanks , how's you ?
# Remove Puncuation:  loltrish hey  long time no see yes rains a bit only a bit  lol  im fine thanks  hows you
# Remove stopwords:  loltrish hey  long time no see yes rains a bit only a bit  lol  im fine thanks  hows you
# lowercase:  @tatiana_k nope they didn't have it
# Remove Puncuation:  tatianak nope they didnt have it
# Remove stopwords:  tatianak nope they didnt have it
# lowercase:  @twittera que me muera ?
# Remove Puncuation:  twittera que me muera
# Remove stopwords:  twittera que me muera
# cleaned_text 0    switchfoot httptwitpiccom2y1zl awww thats bumm...
# 1    upset cant update facebook texting might cry r...
# 2    kenichan dived many times ball managed save 50...
# 3                     whole body feels itchy like fire
# 4             nationwideclass behaving im mad cant see
# 5                                  kwesidei whole crew
# 6                                             need hug
# 7    loltrish hey long time see yes rains bit bit l...
# 8                                  tatianak nope didnt
# 9                                   twittera que muera
# Name: cleaned_text, dtype: object
# C:\Users\Acer\AppData\Local\Temp/ipykernel_22816/2740371544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['cleaned_text'] = df_subset['text'].apply(clean_prep_text)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Naive Bayes

# %%
#naive bayes classifier
from sklearn.naive_bayes import MultinomialNB
naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(Xtrain_tf, Ytrain)
#predicted y
y_pred = naive_bayes_classifier.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(naive_bayes_classifier , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Naive Bayes Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[167  37]
#  [ 13 191]]
# 0.8774509803921569
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87       204
#            1       0.84      0.94      0.88       204
#
#     accuracy                           0.88       408
#    macro avg       0.88      0.88      0.88       408
# weighted avg       0.88      0.88      0.88       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprNB, tprNB, thresholdsNB = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LRClassification=LogisticRegression()
LRClassification.fit(Xtrain_tf, Ytrain)
y_pred=LRClassification.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest, y_pred))
print(classification_report(Ytest, y_pred))
matrix = plot_confusion_matrix(LRClassification , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Logistic Regression Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[165  39]
#  [ 13 191]]
# 0.8725490196078431
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86       204
#            1       0.83      0.94      0.88       204
#
#     accuracy                           0.87       408
#    macro avg       0.88      0.87      0.87       408
# weighted avg       0.88      0.87      0.87       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprLR, tprLR, thresholdsLR = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
DTClassification=DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
DTClassification.fit(Xtrain_tf, Ytrain)
y_pred=DTClassification.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(DTClassification , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Decision Tree Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[187  17]
#  [ 47 157]]
# 0.8431372549019608
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85       204
#            1       0.90      0.77      0.83       204
#
#     accuracy                           0.84       408
#    macro avg       0.85      0.84      0.84       408
# weighted avg       0.85      0.84      0.84       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprDT, tprDT, thresholdsDT = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # SVM

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear') # Linear Kernel
#Train the model using the training sets
clf.fit(Xtrain_tf, Ytrain)
#Predict the response for test dataset
y_pred = clf.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(clf , Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for SVM Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[179  25]
#  [ 14 190]]
# 0.9044117647058824
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       204
#            1       0.88      0.93      0.91       204
#
#     accuracy                           0.90       408
#    macro avg       0.91      0.90      0.90       408
# weighted avg       0.91      0.90      0.90       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprSVM, tprSVM, thresholdsSVM = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=100, criterion ='entropy', random_state = 0).fit(Xtrain_tf, Ytrain)
y_pred=rf_classifier.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(rf_classifier, Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Random Forest Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[149  55]
#  [ 13 191]]
# 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81       204
#            1       0.78      0.94      0.85       204
#
#     accuracy                           0.83       408
#    macro avg       0.85      0.83      0.83       408
# weighted avg       0.85      0.83      0.83       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprRF, tprRF, thresholdsRF = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # SGD

# %%
from sklearn.linear_model import SGDClassifier
sgd_classifier = SGDClassifier(loss = 'log',penalty='l2', max_iter=10,random_state=0).fit(Xtrain_tf, Ytrain)
y_pred=sgd_classifier.predict(Xtest_tf)
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %%
print(confusion_matrix(Ytest,y_pred))
print(accuracy_score(Ytest,y_pred))
print(classification_report(Ytest,y_pred))
matrix = plot_confusion_matrix(sgd_classifier, Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for SGD Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[177  27]
#  [ 16 188]]
# 0.8946078431372549
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89       204
#            1       0.87      0.92      0.90       204
#
#     accuracy                           0.89       408
#    macro avg       0.90      0.89      0.89       408
# weighted avg       0.90      0.89      0.89       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprSGD, tprSGD, thresholdsSGD = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # RandomizerSearchCV

# %%
svm_clf = svm.SVC(probability = True, random_state = 1)
auc = make_scorer(roc_auc_score)
 
# RANDOM SEARCH FOR 20 COMBINATIONS OF PARAMETERS
rand_list = {"C": stats.uniform(2, 10),
             "gamma": stats.uniform(0.1, 1),
             'kernel': ['rbf']}
              
rand_search = RandomizedSearchCV(svm_clf , param_distributions = rand_list, n_iter = 20, n_jobs = 4, cv = 3, random_state = 2017, scoring = auc) 
rand_search.fit(Xtrain_tf, Ytrain) 
rand_search.cv_results_
rand_predictions = rand_search.predict(Xtest_tf)

# %%
print(confusion_matrix(Ytest,rand_predictions))
print(accuracy_score(Ytest,rand_predictions))
print(classification_report(Ytest,rand_predictions))
matrix = plot_confusion_matrix(rand_search, Xtest_tf, Ytest, cmap=plt.cm.Reds)
matrix.ax_.set_title('Confusion Matrix Plot for Random Forest Classifier', color='black')
plt.xlabel('Predicted Label', color='black')
plt.ylabel('True Label', color='black')
plt.gcf().axes[0].tick_params(colors='black')
plt.gcf().axes[1].tick_params(colors='black')
plt.gcf().set_size_inches(10,6)
plt.show()
# Out:
# [[180  24]
#  [ 14 190]]
# 0.9068627450980392
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       204
#            1       0.89      0.93      0.91       204
#
#     accuracy                           0.91       408
#    macro avg       0.91      0.91      0.91       408
# weighted avg       0.91      0.91      0.91       408
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
fprSVM_optimized, tprSVM_optimized, thresholds_optimized = metrics.roc_curve(Ytest,y_pred)

# %% [markdown]
# # ROC

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import auc

plt.figure(1)
plt.figure(figsize=(8, 6), dpi=300)
plt.plot([0, 1], [0, 1], 'k--')

auc_NB = auc(fprNB, tprNB)
auc_LR = auc(fprLR, tprLR)
auc_DT = auc(fprDT , tprDT)
auc_SVM = auc(fprSVM, tprSVM)
auc_RF = auc(fprRF, tprRF)
auc_SGD = auc(fprSGD, tprSGD)
auc_SVM_optimized = auc(fprSVM_optimized, tprSVM_optimized)

plt.plot(fprNB, tprNB, label='Naive Bayes (area = {:.3f})'.format(auc_NB))
plt.plot(fprLR, tprLR, label='Logistic Regression (area = {:.3f})'.format(auc_LR))
plt.plot(fprDT, tprDT, label='Decision Tree (area = {:.3f})'.format(auc_DT))
plt.plot(fprSVM, tprSVM, label='SVM (area = {:.3f})'.format(auc_SVM))
plt.plot(fprRF, tprRF, label='Random Forest (area = {:.3f})'.format(auc_RF))
plt.plot(fprSGD, tprSGD, label='SGD (area = {:.3f})'.format(auc_SGD))
plt.plot(fprSVM_optimized, tprSVM_optimized, label='SVM after RandomizedSearchCV (area = {:.3f})'.format(auc_SVM_optimized))


plt.legend(loc='lower right')
plt.show()
